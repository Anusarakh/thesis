# %% [markdown]
# <a href="https://colab.research.google.com/github/Anusarakh/thesis/blob/main/music_Ex_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import csv

# %%
y, sr = librosa.load(librosa.ex('libri1'))
mfcc_test = librosa.feature.mfcc(y=y, sr=44100, S=None, n_mfcc=20)

# %%
y
# Out:
# array([0.00037424, 0.00036333, 0.00024905, ..., 0.00101743, 0.0023917 ,
#        0.00200722], dtype=float32)

# %%
mfccScaled = np.mean(mfcc_test.T, axis=0) #axis=0 คือทำงานในแนวคอลัมล์
mfccScaled
# Out:
# array([-276.66803  ,  161.87306  ,  -24.257978 ,   34.798256 ,
#          10.438065 ,    2.7754219,   -7.935828 ,   12.72298  ,
#           5.517527 ,    1.1601148,   -3.810489 ,   -5.310315 ,
#          -7.7707624,  -12.147796 ,   -8.521856 ,   -6.415033 ,
#          -1.157337 ,   -0.6646697,    1.4520893,   -3.2086906],
#       dtype=float32)

# %%
df_mfccScaled = pd.DataFrame(mfccScaled)
df_mfccScaled
# Out:
#              0
# 0  -276.668030
# 1   161.873062
# 2   -24.257978
# 3    34.798256
# 4    10.438065
# 5     2.775422
# 6    -7.935828
# 7    12.722980
# 8     5.517527
# 9     1.160115
# 10   -3.810489
# 11   -5.310315
# 12   -7.770762
# 13  -12.147796
# 14   -8.521856
# 15   -6.415033
# 16   -1.157337
# 17   -0.664670
# 18    1.452089
# 19   -3.208691

# %%
len(y)
# Out:
# 327222

# %%
df_ = pd.DataFrame(mfcc_test)
df_
# Out:
#            0           1           2           3           4           5    \
# 0  -580.563782 -579.043213 -578.655518 -574.975403 -568.155457 -563.104309
# 1    14.942307   16.862049   16.191315   20.091843   28.848083   36.064285
# 2    13.763187   15.147621   11.621872   12.518572   19.190315   26.360775
# 3    12.584791   13.479251    7.308465    5.555863   10.279902   16.769608
# 4    11.935865   12.662352    5.671687    3.335501    7.393722   12.366469
# 5    11.786961   12.664164    6.987242    6.330148   11.171232   14.222211
# 6    11.592858   12.668779    9.313227   11.276693   17.454338   18.989939
# 7    10.744301   11.749119   10.028494   13.789093   20.565689   21.560665
# 8     9.069759    9.623350    7.786139   11.569662   17.438454   18.743156
# 9     6.989947    6.899542    3.427038    5.822505    9.541170   11.304214
# 10    5.204023    4.618204   -0.760768    0.001913    1.389886    3.051821
# ...

# %%
mfcc_mean = mfcc_test.mean()
mfcc_mean
# Out:
# -6.3565636

# %%
zcr = librosa.feature.zero_crossing_rate(y)
zcr

zcrScaled = np.mean(zcr.T, axis=0) #axis=0 คือทำงานในแนวคอลัมล์
zcrScaled
# Out:
# array([0.05833511])

# %%
df_zero = pd.DataFrame(zcr)
df_zero
# Out:
#         0         1         2         3         4        5        6    \
# 0  0.029297  0.046875  0.056641  0.054199  0.041504  0.03125  0.03125
#
#         7        8         9    ...       630       631       632       633  \
# 0  0.040039  0.05957  0.069824  ...  0.022461  0.019043  0.016602  0.017578
#
#         634       635      636       637       638       639
# 0  0.016602  0.035645  0.05127  0.064453  0.066895  0.043457
#
# [1 rows x 640 columns]

# %%
zcr_mean = zcr.mean()
zcr_mean
# Out:
# 0.05833511352539063

# %%
import matplotlib.pyplot as plt
import scipy

# %%
lpc_test = librosa.lpc(y, order=1, axis=-1)
lpc_test
# Out:
# array([ 1.       , -0.9879697], dtype=float32)

# %%
df_lpc_test = pd.DataFrame(lpc_test)
df_lpc_test
# Out:
#          0
# 0  1.00000
# 1 -0.98797

# %%
lpc_test_mean = lpc_test.mean()
lpc_test_mean
# Out:
# 0.0060151517

# %%
spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
spec_cent
# Out:
# array([[1948.53353543, 2065.75323454, 2108.69876753, 1940.67974686,
#         1432.97012779, 1220.54620448, 1424.06811688, 1878.26750961,
#         2019.98083004, 2392.98583544, 2143.85684057, 1773.82589143,
#         1414.4036827 ,  977.48092965,  478.65798467,  555.13839594,
#          675.54403021,  666.94888272,  641.9794709 , 1641.02501568,
#         2182.31101546, 1040.99756461,  666.74507808,  701.19562093,
#          658.53126068,  556.41104492,  484.02689886,  409.69151355,
#          362.55139566,  360.07805904,  418.70314748,  547.45730946,
#          639.73801207,  639.82683927,  598.56218605,  633.54585978,
#          725.6159755 ,  677.06635433,  580.36914101,  694.17553202,
#          850.27198308, 1421.56952594, 1316.58107483, 1263.50715845,
#         1095.54530615,  818.65173713,  832.01570854,  871.74222318,
#          859.26670021,  774.52719562,  714.90333639,  621.49940042,
#          484.68363235,  407.88364609, 1217.12929656, 1386.54852844,
# ...

# %%
spec_cent_mean = spec_cent.mean()
spec_cent_mean
# Out:
# 1147.2592587922977

# %%
df_spec_cent = pd.DataFrame(spec_cent)
df_spec_cent
# Out:
#            0            1            2            3            4    \
# 0  1948.533535  2065.753235  2108.698768  1940.679747  1432.970128
#
#            5            6           7           8            9    ...  \
# 0  1220.546204  1424.068117  1878.26751  2019.98083  2392.985835  ...
#
#           630         631         632         633          634          635  \
# 0  564.619252  444.882319  473.510611  818.027129  1116.746677  1071.752333
#
#            636          637          638          639
# 0  1213.875965  1509.856066  1550.391715  1497.810287
#
# [1 rows x 640 columns]

# %%
time_step = 1

# %%
Power_Spectrum = np.fft.fftfreq(y.size, time_step)
Power_Spectrum
# Out:
# array([ 0.00000000e+00,  3.05602924e-06,  6.11205848e-06, ...,
#        -9.16808772e-06, -6.11205848e-06, -3.05602924e-06])

# %%
df_Power_Spectrum = pd.DataFrame(Power_Spectrum)
df_Power_Spectrum
# Out:
#                0
# 0       0.000000
# 1       0.000003
# 2       0.000006
# 3       0.000009
# 4       0.000012
# ...          ...
# 327217 -0.000015
# 327218 -0.000012
# 327219 -0.000009
# 327220 -0.000006
# 327221 -0.000003
#
# [327222 rows x 1 columns]

# %%
Power_Spectrum_mean = Power_Spectrum.mean()
Power_Spectrum_mean
# Out:
# -1.5280146200513542e-06

# %% [markdown]
# #สร้างตาราง

# %%
name = [{'mfcc_mean':'-6.3565636', 'lpc_test_mean':'0.0060151517', 'spec_cent_mean':'1147.2592587922977', 'zcr_mean':'0.05833511352539063', 'Power_Spectrum_mean':'-1.5280146200513542e-06'}]

# %%
data_ = [[-6.3565636], [0.0060151517], [1147.2592587922977], [0.05833511352539063], [-1.5280146200513542e-06]]
data_
# Out:
# [[-6.3565636],
#  [0.0060151517],
#  [1147.2592587922977],
#  [0.05833511352539063],
#  [-1.5280146200513542e-06]]

# %%
data_set = pd.DataFrame(name)
data_set
# Out:
#     mfcc_mean lpc_test_mean      spec_cent_mean             zcr_mean  \
# 0  -6.3565636  0.0060151517  1147.2592587922977  0.05833511352539063
#
#        Power_Spectrum_mean
# 0  -1.5280146200513542e-06

# %%
tonnezt = librosa.feature.tonnetz( y=y, sr=44100, chroma=None)
tonnezt
# Out:
# array([[-0.00025474,  0.004947  ,  0.00785755, ..., -0.05617889,
#         -0.05030206, -0.05102602],
#        [-0.00103631, -0.00644895, -0.00499784, ...,  0.02428073,
#          0.00960029,  0.00714675],
#        [ 0.01337524,  0.01654461,  0.02057866, ..., -0.03185244,
#         -0.01956078, -0.01052299],
#        [-0.02947187, -0.03157765, -0.03394368, ..., -0.14900953,
#         -0.14455618, -0.13819329],
#        [ 0.00979501,  0.01164257,  0.01392158, ...,  0.0349659 ,
#          0.02739622,  0.02397067],
#        [ 0.0227814 ,  0.02030941,  0.01552781, ...,  0.00547706,
#          0.00670638,  0.00367871]])

# %%
df_Tonnezt = pd.DataFrame(tonnezt)
df_Tonnezt
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.000255  0.004947  0.007858  0.009797  0.011642  0.009119  0.007442
# 1 -0.001036 -0.006449 -0.004998 -0.003445 -0.002731  0.003002  0.006522
# 2  0.013375  0.016545  0.020579  0.027742  0.025301  0.018045  0.006717
# 3 -0.029472 -0.031578 -0.033944 -0.034525 -0.032415 -0.036749 -0.047527
# 4  0.009795  0.011643  0.013922  0.015688  0.015692  0.012529  0.009183
# 5  0.022781  0.020309  0.015528  0.010238  0.005567  0.002738  0.000854
#
#         7         8         9    ...       630       631       632       633  \
# 0  0.005956  0.007588  0.016739  ... -0.115475 -0.101142 -0.096908 -0.085380
# 1  0.010936  0.013615  0.013729  ...  0.125268  0.101666  0.087980  0.071626
# 2 -0.000173 -0.010266 -0.012813  ... -0.105477 -0.095112 -0.083506 -0.067741
# 3 -0.062063 -0.074700 -0.079710  ... -0.169918 -0.165490 -0.166758 -0.169066
# 4  0.006884  0.008109  0.013102  ...  0.058620  0.060097  0.058232  0.055498
# ...

# %%
tonneztScaled = np.mean(tonnezt.T, axis=0) #axis=0 คือทำงานในแนวคอลัมล์
tonneztScaled
# Out:
# array([ 0.01015276, -0.00456723,  0.01240696, -0.02048932,  0.00201617,
#        -0.00802679])

# %%
df_tonneztScaled = pd.DataFrame(tonneztScaled)
df_tonneztScaled
# Out:
#           0
# 0  0.010153
# 1 -0.004567
# 2  0.012407
# 3 -0.020489
# 4  0.002016
# 5 -0.008027

# %% [markdown]
# # Spectral Bandwidth

# %%
spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=44100, S=None)

# %%
spectral_bandwidth
# Out:
# array([[5293.59087317, 5229.3145747 , 5116.498126  , 5090.03587512,
#         4643.57970918, 4373.10267432, 4726.6706444 , 5307.37880753,
#         5497.03691049, 5741.84347023, 5566.7800971 , 4787.341417  ,
#         3747.24226161, 3211.25303142, 1598.95313965, 1511.76349524,
#         1634.99329058, 1759.70658931, 2209.72306436, 4357.46825687,
#         4317.01947535, 3092.83600368, 1860.40502942, 1545.5660013 ,
#         1365.82865061, 1327.13545189, 1510.92276559, 1473.75766624,
#         1274.69166778, 1380.26428181, 1132.35727611, 1099.4799065 ,
#         1177.29765015, 1293.97612802, 1535.55592302, 1959.60180807,
#         2280.40138078, 2233.02829403, 2112.32475323, 2562.16963684,
#         2955.47110468, 3617.33530738, 3487.14601531, 3234.11084931,
#         2780.90390896, 2573.16296898, 2428.58876605, 2426.11175861,
#         2463.96432143, 2458.90599266, 2337.38610621, 2108.23231012,
#         1801.22957097, 1700.70017689, 2878.23376344, 2918.70194993,
# ...

# %%
df_spectral_bandwidth = pd.DataFrame(spectral_bandwidth)
df_spectral_bandwidth
# Out:
#            0            1            2            3            4    \
# 0  5293.590873  5229.314575  5116.498126  5090.035875  4643.579709
#
#            5            6            7           8           9    ...  \
# 0  4373.102674  4726.670644  5307.378808  5497.03691  5741.84347  ...
#
#            630          631          632          633         634  \
# 0  1930.056883  1884.001957  2102.729071  2999.673775  3434.16916
#
#            635          636          637          638         639
# 0  3370.595613  3283.852751  3393.639422  3500.517693  3606.15554
#
# [1 rows x 640 columns]

# %% [markdown]
# #tempo

# %%
tempo = librosa.feature.tempo(y=y, sr=44100,onset_envelope=None,
                              tg=None, hop_length=256, start_bpm=120,
                              std_bpm=1.0, ac_size=8.0, max_tempo=320.0,
                              prior=None)
tempo
# Out:
# array([134.23295455])

# %%
df_tempo = pd.DataFrame(tempo)
df_tempo
# Out:
#             0
# 0  134.232955
