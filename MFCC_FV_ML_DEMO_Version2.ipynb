# %% [markdown]
# <a href="https://colab.research.google.com/github/Anusarakh/thesis/blob/main/MFCC_FV_ML_DEMO_Version2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1️⃣ เชื่อม google drive

# %%
#เชื่อม google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#เข้าไป path ใน google drive
import os
os.chdir('/content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิพนธ์/เพลง/')

# !pwd #เช็ค paht ที่กำลังทำงานอยู่
# Out:
# /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิพนธ์/เพลง

# %% [markdown]
# # 2️⃣ Data preparation by MFCC FV

# %%
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import csv
import scipy.io.wavfile as wav

# %%
classes_1 = 1
classes_0 = 0

path_0 = '/content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิพนธ์/เพลง/เพลงที่โรคซึมเศร้าไม่ควรฟัง/'
path_1 = '/content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิพนธ์/เพลง/เพลงสำหรับโรคซึมเศร้า/'

# %%
x_list = os.listdir(path_0)
mfcc_mean_0 = []
mfcc_var_0 = []
spec_cen_mean_0 = []
spec_cen_var_0 = []
classes_0_ = []
for i in x_list:
  x , sr = librosa.load(path_0+i, sr=44100)
  mfcc = librosa.feature.mfcc(y=x, sr=44100 ,n_mfcc= 20, n_fft = 512,  hop_length=256 )
  df_mfcc = pd.DataFrame(mfcc)
  mfcc_mean = df_mfcc.mean(axis = 1) #หาค่าเฉลี่ยในแต่ละลำดับข้อมูล MFCC
  mfcc_var= df_mfcc.var(axis = 1) #หาค่าความแปรปรวนในแต่ละลำดับข้อมูล MFCC
  spec_cen = librosa.feature.spectral_centroid(y=x, sr=44100, S=None, n_fft=512, hop_length=256)
  df_spec_cen = pd.DataFrame(spec_cen)
  spec_cen_mean = df_spec_cen.mean(axis = 1) #หาค่าเฉลี่ยในแต่ละลำดับข้อมูล spectral_centroid
  spec_cen_var= df_spec_cen.var(axis = 1) #หาค่าความแปรปรวนในแต่ละลำดับข้อมูล spectral_centroid
  mfcc_mean_0.append(list(mfcc_mean))
  mfcc_var_0.append(list(mfcc_var))
  spec_cen_mean_0.append(list(spec_cen_mean))
  spec_cen_var_0.append(list(spec_cen_var))
  classes_0_.append(path_0+i)
# Out:
# /usr/local/lib/python3.10/dist-packages/librosa/feature/spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)

# %%
x_list = os.listdir(path_1)
mfcc_mean_1 = []
mfcc_var_1 = []
spec_cen_mean_1 = []
spec_cen_var_1 = []
classes_1_ = []
for i in x_list:
  x , sr = librosa.load(path_1+i, sr=44100)
  mfcc = librosa.feature.mfcc(y=x, sr=44100 ,n_mfcc= 20, n_fft = 512,  hop_length=256 )
  df_mfcc = pd.DataFrame(mfcc)
  mfcc_mean = df_mfcc.mean(axis = 1) #หาค่าเฉลี่ยในแต่ละลำดับข้อมูล MFCC
  mfcc_var= df_mfcc.var(axis = 1) #หาค่าความแปรปรวนในแต่ละลำดับข้อมูล MFCC
  spec_cen = librosa.feature.spectral_centroid(y=x, sr=44100, S=None, n_fft=512, hop_length=256)
  df_spec_cen = pd.DataFrame(spec_cen)
  spec_cen_mean = df_spec_cen.mean(axis = 1) #หาค่าเฉลี่ยในแต่ละลำดับข้อมูล spectral_centroid
  spec_cen_var= df_spec_cen.var(axis = 1) #หาค่าความแปรปรวนในแต่ละลำดับข้อมูล spectral_centroid
  mfcc_mean_1.append(list(mfcc_mean))
  mfcc_var_1.append(list(mfcc_var))
  spec_cen_mean_0.append(list(spec_cen_mean))
  spec_cen_var_0.append(list(spec_cen_var))
  classes_1_.append(path_1+i)

# %% [markdown]
# ###สร้าง Data set + class

# %%
mfcc_mean_0 = np.array(mfcc_mean_0)
mfcc_mean_1 = np.array(mfcc_mean_1)

mfcc_mean_df = pd.DataFrame(data = mfcc_mean_0)
mfcc_mean_df['y'] = 0
mfcc_mean_df['path'] = classes_0_
mfcc_mean_df_1 = pd.DataFrame(data = mfcc_mean_1)
mfcc_mean_df_1['y'] = 1
mfcc_mean_df_1['path'] = classes_1_

df_mean = mfcc_mean_df.append(mfcc_mean_df_1)

print(df_mean.shape)
df_mean.head()
# Out:
# (48, 22)
# <ipython-input-38-dd538f5c535a>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mean = mfcc_mean_df.append(mfcc_mean_df_1)
#             0           1          2          3         4          5  \
# 0 -538.598083  113.478355 -26.311657  14.285193 -2.615120  20.236992
# 1 -534.914490  130.501404  20.693159  -0.368550  3.864216  10.282823
# 2 -341.382050   87.907219 -68.019501  21.463785 -9.300843  29.104156
# 3 -341.382050   87.907219 -68.019501  21.463785 -9.300843  29.104156
# 4 -333.593781   89.235611 -48.172359  33.847538  0.143549  21.800449
#
#           6          7          8          9  ...         12        13  \
# 0 -7.610242   1.884620 -11.387437 -11.193010  ... -10.256916 -9.858205
# 1 -7.931257  -3.838516  -6.757467  -8.169674  ...  -3.227062 -7.023374
# 2 -9.891349  10.565740 -14.902565  -4.446410  ...  -1.645562 -4.040006
# 3 -9.891349  10.565740 -14.902565  -4.446410  ...  -1.645562 -4.040006
# 4 -5.154069   3.627782  -8.566092  -2.217165  ...  -5.247314 -2.651468
#
#          14         15        16        17        18        19  y  \
# 0 -8.086324 -10.251784 -2.539678 -4.401006 -0.343688  1.216539  0
# 1 -8.593847 -10.261535 -4.494755 -2.965578 -1.883306 -2.093495  0
# 2 -2.929919  -7.557992  0.327383 -2.359935  3.743439 -2.977661  0
# 3 -2.929919  -7.557992  0.327383 -2.359935  3.743439 -2.977661  0
# 4 -2.322215  -7.671337 -2.934254 -2.611754  1.254204 -3.089329  0
#
#                                                 path
# 0  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 1  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 2  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 3  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 4  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
#
# [5 rows x 22 columns]

# %% [markdown]
# #### รวม mfcc & spect_cen

# %%
mfcc_mean_0 = np.array(mfcc_mean_0)
mfcc_mean_1 = np.array(mfcc_mean_1)

mfcc_mean_df = pd.DataFrame(data = mfcc_mean_0)
mfcc_mean_df['y'] = 0
mfcc_mean_df['path'] = classes_0_
mfcc_mean_df['spec'] = spec_cen_mean_0

mfcc_mean_df_1 = pd.DataFrame(data = mfcc_mean_1)
mfcc_mean_df_1['y'] = 1
mfcc_mean_df_1['path'] = classes_1_
mfcc_mean_df_1['spec'] = spec_cen_mean_1
df_mean = mfcc_mean_df.append(mfcc_mean_df_1)

print(df_mean.shape)
df_mean.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-b4ed73a0f442> in <cell line: 7>()
#       5 mfcc_mean_df['y'] = 0
#       6 mfcc_mean_df['path'] = classes_0_
# ----> 7 mfcc_mean_df['spec'] = spec_cen_mean_0
#       8
#       9 mfcc_mean_df_1 = pd.DataFrame(data = mfcc_mean_1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3978         else:
#    3979             # set column
# -> 3980             self._set_item(key, value)
#    3981
#    3982     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4172         ensure homogeneity.
#    4173         """
# -> 4174         value = self._sanitize_column(value)
#    4175
#    4176         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4913
#    4914         if is_list_like(value):
# -> 4915             com.require_length_match(value, self.index)
#    4916         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4917
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     569     """
#     570     if len(data) != len(index):
# --> 571         raise ValueError(
#     572             "Length of values "
#     573             f"({len(data)}) "
#
# ValueError: Length of values (48) does not match length of index (10)

# %%
mfcc_spec_mean_df
# Out:
#                                                    0  y
# 0  [[-538.5980834960938, 113.47835540771484, -26....  0
# 1  [[2310.1757505174696], [2310.1757505174696], [...  0

# %%
mfcc_var_0 = np.array(mfcc_var_0)
mfcc_var_1 = np.array(mfcc_var_1)

mfcc_var_df = pd.DataFrame(data = mfcc_var_0)
mfcc_var_df['y'] = 0
mfcc_var_df['path'] = classes_0_
mfcc_var_df_1 = pd.DataFrame(data = mfcc_var_1)
mfcc_var_df_1['y'] = 1
mfcc_var_df_1['path'] = classes_1_

df_var = mfcc_var_df.append(mfcc_var_df_1)

print(df_var.shape)
df_var.head()
# Out:
# (48, 22)
# <ipython-input-12-78b4aa0f8448>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_var = mfcc_var_df.append(mfcc_var_df_1)
#               0            1            2           3           4           5  \
# 0   6561.428223  1127.236450   565.417603  303.133636  255.959793  276.573883
# 1   4009.359131  1089.997192  1040.547729  422.518219  400.780884  209.632507
# 2  14482.233398  1044.295288  1383.855957  323.438995  297.298523  281.603790
# 3  14482.233398  1044.295288  1383.855957  323.438995  297.298523  281.603790
# 4  10859.018555   859.810120  1678.833862  457.918030  253.008789  201.193680
#
#             6           7           8           9  ...         12         13  \
# 0  164.443237  127.473534  124.954865  124.061928  ...  89.594589  93.370056
# 1  223.919724   98.633492  104.409950   94.473648  ...  53.548553  64.388252
# 2  136.930908   93.439362  100.023468   85.098595  ...  71.563042  67.520973
# 3  136.930908   93.439362  100.023468   85.098595  ...  71.563042  67.520973
# 4  200.928528  134.568466  114.754135  121.568726  ...  74.413422  70.515297
#
#           14         15         16         17          18         19  y  \
# 0  85.432297  92.360451  94.520683  70.736496  102.250626  69.246078  0
# 1  71.411934  62.692402  51.107048  53.768761   47.618454  44.006294  0
# 2  70.997841  66.438942  50.856522  49.642475   57.333076  47.380219  0
# 3  70.997841  66.438942  50.856522  49.642475   57.333076  47.380219  0
# 4  58.266571  65.791122  58.746487  56.237946   57.182301  50.608665  0
#
#                                                 path
# 0  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 1  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 2  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 3  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 4  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 1  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 2  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 3  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
# 4  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...
#
# [5 rows x 22 columns]

# %%
path = df_mean[df_mean['y']== 0]['path'].tolist()
# print(len(path))
from random import sample
res_samle_0 = sample(path,int(len(path)*0.8))
print(len(set(res_samle_0)))

path = df_mean[df_mean['y']== 1]['path'].tolist()
# print(len(path))
from random import sample
res_samle_1 = sample(path,int(len(path)*0.8))
print(len(set(res_samle_1)))

res_samle_0.extend(res_samle_1)

print(len(res_samle_0))
# Out:
# 8
# 30
# 38

# %%
train = df_mean[df_mean['path'].isin(res_samle_0)]
train['split'] = 'train'
test = df_mean[~df_mean['path'].isin(res_samle_0)]
test['split'] = 'test'

df_all = train.append(test)
print(df_all.shape)
df_all.head()
# Out:
# (48, 23)
# <ipython-input-15-d13c214b5ed7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['split'] = 'train'
# <ipython-input-15-d13c214b5ed7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['split'] = 'test'
# <ipython-input-15-d13c214b5ed7>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = train.append(test)
#             0           1          2          3         4          5  \
# 0 -538.598083  113.478355 -26.311657  14.285193 -2.615120  20.236992
# 1 -534.914490  130.501404  20.693159  -0.368550  3.864216  10.282823
# 2 -341.382050   87.907219 -68.019501  21.463785 -9.300843  29.104156
# 3 -341.382050   87.907219 -68.019501  21.463785 -9.300843  29.104156
# 4 -333.593781   89.235611 -48.172359  33.847538  0.143549  21.800449
#
#           6          7          8          9  ...        13        14  \
# 0 -7.610242   1.884620 -11.387437 -11.193010  ... -9.858205 -8.086324
# 1 -7.931257  -3.838516  -6.757467  -8.169674  ... -7.023374 -8.593847
# 2 -9.891349  10.565740 -14.902565  -4.446410  ... -4.040006 -2.929919
# 3 -9.891349  10.565740 -14.902565  -4.446410  ... -4.040006 -2.929919
# 4 -5.154069   3.627782  -8.566092  -2.217165  ... -2.651468 -2.322215
#
#           15        16        17        18        19  y  \
# 0 -10.251784 -2.539678 -4.401006 -0.343688  1.216539  0
# 1 -10.261535 -4.494755 -2.965578 -1.883306 -2.093495  0
# 2  -7.557992  0.327383 -2.359935  3.743439 -2.977661  0
# 3  -7.557992  0.327383 -2.359935  3.743439 -2.977661  0
# 4  -7.671337 -2.934254 -2.611754  1.254204 -3.089329  0
#
#                                                 path  split
# 0  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
# 1  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
# 2  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
# 3  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
# 4  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
#
# [5 rows x 23 columns]

# %%
# var fv same table
df_var['split'] = df_var['path'].map(df_all.set_index('path')['split']) # can map column split by path column
df_var.head()
# Out:
#               0            1            2           3           4           5  \
# 0   6561.428223  1127.236450   565.417603  303.133636  255.959793  276.573883
# 1   4009.359131  1089.997192  1040.547729  422.518219  400.780884  209.632507
# 2  14482.233398  1044.295288  1383.855957  323.438995  297.298523  281.603790
# 3  14482.233398  1044.295288  1383.855957  323.438995  297.298523  281.603790
# 4  10859.018555   859.810120  1678.833862  457.918030  253.008789  201.193680
#
#             6           7           8           9  ...         13         14  \
# 0  164.443237  127.473534  124.954865  124.061928  ...  93.370056  85.432297
# 1  223.919724   98.633492  104.409950   94.473648  ...  64.388252  71.411934
# 2  136.930908   93.439362  100.023468   85.098595  ...  67.520973  70.997841
# 3  136.930908   93.439362  100.023468   85.098595  ...  67.520973  70.997841
# 4  200.928528  134.568466  114.754135  121.568726  ...  70.515297  58.266571
#
#           15         16         17          18         19  y  \
# 0  92.360451  94.520683  70.736496  102.250626  69.246078  0
# 1  62.692402  51.107048  53.768761   47.618454  44.006294  0
# 2  66.438942  50.856522  49.642475   57.333076  47.380219  0
# 3  66.438942  50.856522  49.642475   57.333076  47.380219  0
# 4  65.791122  58.746487  56.237946   57.182301  50.608665  0
#
#                                                 path  split
# 0  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
# 1  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
# 2  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
# 3  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
# 4  /content/gdrive/MyDrive/Thesis/เค้าโครงวิทยานิ...  train
#
# [5 rows x 23 columns]

# %% [markdown]
# # 3️⃣ Machine Learning testing // Random Forest Classifier

# %% [markdown]
# ## ML with var fv

# %%
train = df_var[df_var['split'] =='train']
test = df_var[df_var['split'] !='train']
X_train = train.iloc[:, 0:20]
X_test = test.iloc[:, 0:20]
y_train = train.iloc[:, -3]
y_test = test.iloc[:, -3]

# %%
import os
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# %%
n_estimators = [400]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100]
forest = RandomForestClassifier(random_state = 1)
hyperF ={'n_estimators' : n_estimators, 'max_depth' : max_depth, 'min_samples_split' : min_samples_split}
gridF = GridSearchCV(forest, hyperF, cv = 3, verbose = 1, n_jobs = -1)
bestF = gridF.fit(X_train, y_train)
bestF_ = bestF.best_params_

forestOpt = RandomForestClassifier(random_state = 1, max_depth = bestF_['max_depth'], n_estimators = bestF_['n_estimators'], min_samples_split =bestF_['min_samples_split'])
modelOpt = forestOpt.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits

# %%
print(bestF_)
# Out:
# {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}

# %%
y_pred = modelOpt.predict(X_test)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.89      1.00      0.94         8
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
# [[1 1]
#  [0 8]]

# %% [markdown]
# ## ML with mean fv

# %%
train = df_all[df_all['split'] =='train']
test = df_all[df_all['split'] !='train']
X_train = train.iloc[:, 0:20]
X_test = test.iloc[:, 0:20]
y_train = train.iloc[:, -3]
y_test = test.iloc[:, -3]

n_estimators = [400]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100]
forest = RandomForestClassifier(random_state = 1)
hyperF ={'n_estimators' : n_estimators, 'max_depth' : max_depth, 'min_samples_split' : min_samples_split}
gridF = GridSearchCV(forest, hyperF, cv = 3, verbose = 1, n_jobs = -1)
bestF = gridF.fit(X_train, y_train)
bestF_ = bestF.best_params_

forestOpt = RandomForestClassifier(random_state = 1, max_depth = bestF_['max_depth'], n_estimators = bestF_['n_estimators'], min_samples_split =bestF_['min_samples_split'])
modelOpt = forestOpt.fit(X_train, y_train)

print(bestF_)
# Out:
# Fitting 3 folds for each of 25 candidates, totalling 75 fits
# {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}

# %%
y_pred = modelOpt.predict(X_test)
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.89      1.00      0.94         8
#
#     accuracy                           0.90        10
#    macro avg       0.94      0.75      0.80        10
# weighted avg       0.91      0.90      0.89        10
#
# [[1 1]
#  [0 8]]
